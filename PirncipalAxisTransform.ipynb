# %%
# %matplotlib inline

# %% [markdown]
# # Principal Axis Transform

# %%
def generate_known_gaussian(dimensions, num_of_samples=100):
        
    ret = []
    ret.append(tuple((np.random.normal(0,1)) for _ in range(num_of_samples)
                                             for d in range(dimensions)))   
    return ret

# %%
np.random.normal(0,1)
# Out:
# 3.3771079081158373

# %%
generate_known_gaussian(2, 100)
# Out:
# [(0.632301377383818,
#   1.2783664066909275,
#   -1.0647213762934409,
#   0.5241108167864771,
#   -0.36799140295276367,
#   -0.5333004132242758,
#   0.24751019249757025,
#   0.6811943563303446,
#   -0.6956078059857382,
#   -0.36025613318856853,
#   -0.08921595066576346,
#   0.06659399433137321,
#   0.11247830575243642,
#   0.009836413754736881,
#   -0.6688183349896636,
#   0.33407959879064886,
#   -0.451613838204434,
#   -0.00993535859088265,
#   1.7068401172300047,
#   1.9421617586668751,
#   0.8280751566927033,
#   0.7670916576874802,
#   1.399540116550788,
#   0.5082580014498744,
#   -0.5776626495498167,
#   -1.2271421188699325,
#   1.1306050009119422,
#   1.5078943562126406,
#   0.9726940576820349,
#   0.3652128119685634,
#   0.3122107945974467,
#   0.6910261193926778,
#   0.2444763531479198,
#   -0.0816165215470514,
#   0.44465841133907474,
#   -1.033731716193135,
#   0.2841312287070669,
#   0.9573208659689599,
#   0.3834268796912578,
#   -0.3136494208143567,
# ...
